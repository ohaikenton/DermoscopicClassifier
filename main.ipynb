# %% [markdown]
# # Dermoscopic Image Classification

# %% [markdown]
# ### Check GPU Status

# %%
# !nvidia-smi

# %%
# !pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.23.2 in d:\developer\dermoscopicclassifier\.venv\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in d:\developer\dermoscopicclassifier\.venv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.5 in d:\developer\dermoscopicclassifier\.venv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Downloading pandas-2.2.2-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    -- ------------------------------------- 0.7/11.6 MB 23.5 MB/s eta 0:00:01
#    ----- ---------------------------------- 1.5/11.6 MB 15.8 MB/s eta 0:00:01
#    ------- -------------------------------- 2.2/11.6 MB 15.3 MB/s eta 0:00:01
#    --------- ------------------------------ 2.6/11.6 MB 13.9 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.3/11.6 MB 14.9 MB/s eta 0:00:01
#    ------------ --------------------------- 3.8/11.6 MB 13.4 MB/s eta 0:00:01
#    --------------- ------------------------ 4.4/11.6 MB 14.0 MB/s eta 0:00:01
#    ----------------- ---------------------- 4.9/11.6 MB 13.2 MB/s eta 0:00:01
#    ------------------ --------------------- 5.5/11.6 MB 13.6 MB/s eta 0:00:01
#    --------------------- ------------------ 6.1/11.6 MB 13.5 MB/s eta 0:00:01
#    ----------------------- ---------------- 6.7/11.6 MB 13.4 MB/s eta 0:00:01
#    ------------------------- -------------- 7.4/11.6 MB 13.6 MB/s eta 0:00:01
#    --------------------------- ------------ 8.1/11.6 MB 13.6 MB/s eta 0:00:01
#    ------------------------------ --------- 8.8/11.6 MB 13.7 MB/s eta 0:00:01
#    -------------------------------- ------- 9.4/11.6 MB 13.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 10.0/11.6 MB 13.6 MB/s eta 0:00:01
#    ------------------------------------ --- 10.5/11.6 MB 13.1 MB/s eta 0:00:01
#    ------------------------------------- -- 11.0/11.6 MB 13.1 MB/s eta 0:00:01
#    ---------------------------------------  11.6/11.6 MB 12.8 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 12.6 MB/s eta 0:00:00
# Downloading pytz-2024.1-py2.py3-none-any.whl (505 kB)
#    ---------------------------------------- 0.0/505.5 kB ? eta -:--:--
#    --------------------------------------- 505.5/505.5 kB 10.5 MB/s eta 0:00:00
# Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#    ---------------------------------------- 0.0/345.4 kB ? eta -:--:--
#    --------------------------------------- 345.4/345.4 kB 10.5 MB/s eta 0:00:00
# Installing collected packages: pytz, tzdata, pandas
# Successfully installed pandas-2.2.2 pytz-2024.1 tzdata-2024.1

# %%
# Importing the required libraries
import os
import time
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import time
from torch.utils.data import DataLoader, Dataset
from torchvision import transforms, datasets, models

# %% [markdown]
# Define hyperparameters

# %%
batch_size = 4
img_size = 84
num_classes = 8
data_dir = 'data'
sgd_lr = 0.001
sgd_momentum = 0.9
num_epochs = 100

# %% [markdown]
# Checking if GPU is available

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print("Device: ", device)
# Out:
# Device:  cuda

# %%
# Define data transformations
data_transform = {
    'train': transforms.Compose([
        # transforms.Resize((84, 84)),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ]),
    'test': transforms.Compose([
        # transforms.Resize((84, 84)),
        transforms.ToTensor(),
        transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
    ])
}

# %%
image_datasets = {x: datasets.ImageFolder(os.path.join(data_dir, x), data_transform[x]) for x in ['train', 'test']}

# %%
dataloaders = {x: DataLoader(image_datasets[x], batch_size=batch_size, shuffle=True, num_workers=4) for x in ['train', 'test']}
dataset_sizes = {x: len(image_datasets[x]) for x in ['train', 'test']}
print(dataset_sizes)

class_names = image_datasets['train'].classes
print(class_names)
# Out:
# {'train': 24499, 'test': 800}
# ['AK', 'BCC', 'BKL', 'DF', 'MEL', 'NV', 'SCC', 'VASC']

# %%
class CNN(nn.Module):
    def __init__(self):
        super(CNN, self).__init__()
        self.conv1 = nn.Conv2d(3, 32, kernel_size=3, padding=1)
        self.pool = nn.MaxPool2d(2, 2)
        self.conv2 = nn.Conv2d(32, 64, kernel_size=3, padding=1)
        self.conv3 = nn.Conv2d(64, 128, kernel_size=3, padding=1)
        self.conv4 = nn.Conv2d(128, 256, kernel_size=3, padding=1)

        # Calculate the size of the tensor after the last pooling layer
        self.fc_size = 256 * (img_size // 16) * (img_size // 16)

        self.fc1 = nn.Linear(self.fc_size, 512)
        self.fc2 = nn.Linear(512, num_classes)

    def forward(self, x):
        x = self.pool(nn.functional.relu(self.conv1(x)))
        x = self.pool(nn.functional.relu(self.conv2(x)))
        x = self.pool(nn.functional.relu(self.conv3(x)))
        x = self.pool(nn.functional.relu(self.conv4(x)))

        x = x.view(-1, self.fc_size)

        x = nn.functional.relu(self.fc1(x))
        x = self.fc2(x)
        return x

# %%
model = CNN()

for name, param in model.named_parameters():
    if "fc" in name:
        param.requires_grad = True
    else:
        param.requires_grad = False
        
criteria = nn.CrossEntropyLoss()
optimizer = optim.SGD(filter(lambda p: p.requires_grad, model.parameters()), lr=sgd_lr, momentum=sgd_momentum)

model = model.to(device)

# %%
# Create an array to store the results
results = np.empty((0,5))

for epoch in range(num_epochs):
    start_time = time.time()
    print('Epoch {}/{}'.format(epoch, num_epochs - 1))
    print('-' * 10)

    for phase in ['train', 'test']:
        if phase == 'train':
            model.train()
        else:
            model.eval()

        running_loss = 0.0
        running_corrects = 0

        for inputs, labels in dataloaders[phase]:
            inputs = inputs.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()

            with torch.set_grad_enabled(phase == 'train'):
                outputs = model(inputs)
                _, preds = torch.max(outputs, 1)
                loss = criteria(outputs, labels)

                if phase == 'train':
                    loss.backward()
                    optimizer.step()

            running_loss += loss.item() * inputs.size(0)
            running_corrects += torch.sum(preds == labels.data)

        epoch_loss = running_loss / dataset_sizes[phase]
        epoch_acc = running_corrects.double() / dataset_sizes[phase]

        print('{} Loss: {:.4f} Acc: {:.4f}'.format(phase, epoch_loss, epoch_acc))

    end_time = time.time()
    epoch_time = end_time - start_time
    print('Time taken for epoch: {:.0f}m {:.0f}s'.format(epoch_time // 60, epoch_time % 60))

    # Append the results of this epoch to the array
    results = np.append(results, np.array([[epoch, phase, epoch_loss, epoch_acc.cpu(), epoch_time]]), axis=0)
# Out:
# Epoch 0/99
# ----------
# train Loss: 1.2923 Acc: 0.5406
# test Loss: 2.7842 Acc: 0.1713
# Time taken for epoch: 0m 19s
# Epoch 1/99
# ----------
# train Loss: 1.2003 Acc: 0.5657
# test Loss: 2.5760 Acc: 0.2075
# Time taken for epoch: 0m 19s
# Epoch 2/99
# ----------
# train Loss: 1.1668 Acc: 0.5739
# test Loss: 2.7522 Acc: 0.2038
# Time taken for epoch: 0m 19s
# Epoch 3/99
# ----------
# train Loss: 0.9404 Acc: 0.6573
# test Loss: 2.2487 Acc: 0.2600
# Time taken for epoch: 0m 20s
# Epoch 43/99
# ----------
# train Loss: 0.9366 Acc: 0.6594
# test Loss: 2.4724 Acc: 0.2550
# Time taken for epoch: 0m 20s
# Epoch 44/99
# ----------
# train Loss: 0.9324 Acc: 0.6602
# test Loss: 2.2496 Acc: 0.2750
# Time taken for epoch: 0m 20s
# Epoch 45/99
# ----------
# train Loss: 0.9318 Acc: 0.6602
# test Loss: 2.2203 Acc: 0.2888
# Time taken for epoch: 0m 21s
# Epoch 46/99
# ----------
# train Loss: 0.9313 Acc: 0.6601
# test Loss: 2.3051 Acc: 0.2787
# Time taken for epoch: 0m 20s
# Epoch 47/99
# ----------
# train Loss: 0.9264 Acc: 0.6624
# test Loss: 2.3230 Acc: 0.2662
# Time taken for epoch: 0m 20s
# Epoch 48/99
# ----------
# train Loss: 0.9267 Acc: 0.6610
# test Loss: 2.0510 Acc: 0.3050
# Time taken for epoch: 0m 20s
# Epoch 49/99
# ----------
# train Loss: 0.9241 Acc: 0.6634
# test Loss: 2.4506 Acc: 0.2612
# Time taken for epoch: 0m 22s
# Epoch 50/99
# ----------
# train Loss: 0.9222 Acc: 0.6642
# test Loss: 2.2661 Acc: 0.3013
# Time taken for epoch: 0m 21s
# Epoch 51/99
# ----------
# train Loss: 0.9185 Acc: 0.6659
# test Loss: 2.2909 Acc: 0.2787
# Time taken for epoch: 0m 21s
# Epoch 52/99
# ----------
# train Loss: 0.9178 Acc: 0.6678
# test Loss: 2.3346 Acc: 0.2863
# Time taken for epoch: 0m 22s
# Epoch 53/99
# ----------
# train Loss: 0.9174 Acc: 0.6662
# test Loss: 2.2452 Acc: 0.2850
# Time taken for epoch: 0m 21s
# Epoch 54/99
# ----------
# train Loss: 0.9141 Acc: 0.6669
# test Loss: 2.1933 Acc: 0.3050
# Time taken for epoch: 0m 20s
# Epoch 55/99
# ----------
# train Loss: 0.9144 Acc: 0.6660
# test Loss: 2.1424 Acc: 0.2913
# Time taken for epoch: 0m 21s
# Epoch 56/99
# ----------
# train Loss: 0.9096 Acc: 0.6664
# test Loss: 2.1903 Acc: 0.2963
# Time taken for epoch: 0m 20s
# Epoch 57/99
# ----------
# train Loss: 0.9108 Acc: 0.6681
# test Loss: 2.1145 Acc: 0.2950
# Time taken for epoch: 0m 20s
# Epoch 58/99
# ----------
# train Loss: 0.9061 Acc: 0.6681
# test Loss: 2.0480 Acc: 0.3050
# Time taken for epoch: 0m 20s
# Epoch 59/99
# ----------
# train Loss: 0.9042 Acc: 0.6681
# test Loss: 2.0959 Acc: 0.3038
# Time taken for epoch: 0m 19s
# Epoch 60/99
# ----------
# train Loss: 0.9029 Acc: 0.6694
# test Loss: 2.1396 Acc: 0.3088
# Time taken for epoch: 0m 20s
# Epoch 61/99
# ----------
# train Loss: 0.9007 Acc: 0.6717
# test Loss: 2.1910 Acc: 0.3075
# Time taken for epoch: 0m 20s
# Epoch 62/99
# ----------
# train Loss: 0.8977 Acc: 0.6725
# test Loss: 2.3400 Acc: 0.2900
# Time taken for epoch: 0m 19s
# Epoch 63/99
# ----------
# train Loss: 0.8949 Acc: 0.6742
# test Loss: 2.4904 Acc: 0.2575
# Time taken for epoch: 0m 19s
# Epoch 64/99
# ----------
# train Loss: 0.8943 Acc: 0.6744
# test Loss: 2.1753 Acc: 0.3025
# Time taken for epoch: 0m 19s
# Epoch 65/99
# ----------
# train Loss: 0.8946 Acc: 0.6720
# test Loss: 2.1314 Acc: 0.3025
# Time taken for epoch: 0m 19s
# Epoch 66/99
# ----------
# train Loss: 0.8906 Acc: 0.6735
# test Loss: 2.0683 Acc: 0.3138
# Time taken for epoch: 0m 19s
# Epoch 67/99
# ----------
# train Loss: 0.8885 Acc: 0.6743
# test Loss: 2.4339 Acc: 0.2675
# Time taken for epoch: 0m 19s
# Epoch 68/99
# ----------
# train Loss: 0.8868 Acc: 0.6770
# test Loss: 2.3257 Acc: 0.2838
# Time taken for epoch: 0m 19s
# Epoch 69/99
# ----------
# train Loss: 0.8882 Acc: 0.6768
# test Loss: 2.1307 Acc: 0.3125
# Time taken for epoch: 0m 19s
# Epoch 70/99
# ----------
# train Loss: 0.8852 Acc: 0.6766
# test Loss: 2.0983 Acc: 0.3163
# Time taken for epoch: 0m 19s
# Epoch 71/99
# ----------
# train Loss: 0.8820 Acc: 0.6788
# test Loss: 2.1353 Acc: 0.2975
# Time taken for epoch: 0m 19s
# Epoch 72/99
# ----------
# train Loss: 0.8805 Acc: 0.6789
# test Loss: 2.1814 Acc: 0.3013
# Time taken for epoch: 0m 19s
# Epoch 73/99
# ----------
# train Loss: 0.8811 Acc: 0.6790
# test Loss: 2.1253 Acc: 0.3063
# Time taken for epoch: 0m 19s
# Epoch 74/99
# ----------
# train Loss: 0.8776 Acc: 0.6822
# test Loss: 2.2632 Acc: 0.3038
# Time taken for epoch: 0m 19s
# Epoch 75/99
# ----------
# train Loss: 0.8745 Acc: 0.6791
# test Loss: 2.1356 Acc: 0.3100
# Time taken for epoch: 0m 19s
# Epoch 76/99
# ----------
# train Loss: 0.8731 Acc: 0.6800
# test Loss: 2.3692 Acc: 0.2687
# Time taken for epoch: 0m 19s
# Epoch 77/99
# ----------
# train Loss: 0.8721 Acc: 0.6821
# test Loss: 2.3829 Acc: 0.2875
# Time taken for epoch: 0m 19s
# Epoch 78/99
# ----------
# train Loss: 0.8706 Acc: 0.6822
# test Loss: 2.2407 Acc: 0.3088
# Time taken for epoch: 0m 19s
# Epoch 79/99
# ----------
# train Loss: 0.8701 Acc: 0.6798
# test Loss: 2.0838 Acc: 0.3250
# Time taken for epoch: 0m 19s
# Epoch 80/99
# ----------
# train Loss: 0.8684 Acc: 0.6827
# test Loss: 2.4000 Acc: 0.2787
# Time taken for epoch: 0m 19s
# Epoch 81/99
# ----------
# train Loss: 0.8658 Acc: 0.6813
# test Loss: 2.1620 Acc: 0.3287
# Time taken for epoch: 0m 19s
# Epoch 82/99
# ----------
# train Loss: 0.8653 Acc: 0.6818
# test Loss: 2.1615 Acc: 0.3100
# Time taken for epoch: 0m 19s
# Epoch 83/99
# ----------
# train Loss: 0.8613 Acc: 0.6851
# test Loss: 2.0651 Acc: 0.3250
# Time taken for epoch: 0m 19s
# Epoch 84/99
# ----------
# train Loss: 0.8618 Acc: 0.6844
# test Loss: 2.2119 Acc: 0.3113
# Time taken for epoch: 0m 19s
# Epoch 85/99
# ----------
# train Loss: 0.8619 Acc: 0.6807
# test Loss: 2.1653 Acc: 0.3125
# Time taken for epoch: 0m 20s
# Epoch 86/99
# ----------
# train Loss: 0.8542 Acc: 0.6886
# test Loss: 2.2024 Acc: 0.3150
# Time taken for epoch: 0m 19s
# Epoch 87/99
# ----------
# train Loss: 0.8560 Acc: 0.6874
# test Loss: 2.1697 Acc: 0.3138
# Time taken for epoch: 0m 19s
# Epoch 88/99
# ----------
# train Loss: 0.8546 Acc: 0.6853
# test Loss: 2.0558 Acc: 0.3350
# Time taken for epoch: 0m 19s
# Epoch 89/99
# ----------
# train Loss: 0.8528 Acc: 0.6878
# test Loss: 2.0468 Acc: 0.3400
# Time taken for epoch: 0m 19s
# Epoch 90/99
# ----------
# train Loss: 0.8514 Acc: 0.6870
# test Loss: 2.0573 Acc: 0.3212
# Time taken for epoch: 0m 20s
# Epoch 91/99
# ----------
# train Loss: 0.8483 Acc: 0.6883
# test Loss: 2.2719 Acc: 0.2988
# Time taken for epoch: 0m 19s
# Epoch 92/99
# ----------
# train Loss: 0.8477 Acc: 0.6910
# test Loss: 2.0438 Acc: 0.3200
# Time taken for epoch: 0m 19s
# Epoch 93/99
# ----------
# train Loss: 0.8445 Acc: 0.6934
# test Loss: 2.2211 Acc: 0.3150
# Time taken for epoch: 0m 19s
# Epoch 94/99
# ----------
# train Loss: 0.8459 Acc: 0.6914
# test Loss: 2.1365 Acc: 0.3350
# Time taken for epoch: 0m 19s
# Epoch 95/99
# ----------
# train Loss: 0.8432 Acc: 0.6930
# test Loss: 2.2403 Acc: 0.3138
# Time taken for epoch: 0m 19s
# Epoch 96/99
# ----------
# train Loss: 0.8406 Acc: 0.6911
# test Loss: 2.2411 Acc: 0.3287
# Time taken for epoch: 0m 19s
# Epoch 97/99
# ----------
# train Loss: 0.8398 Acc: 0.6919
# test Loss: 2.0966 Acc: 0.3300
# Time taken for epoch: 0m 19s
# Epoch 98/99
# ----------
# train Loss: 0.8399 Acc: 0.6938
# test Loss: 2.0646 Acc: 0.3375
# Time taken for epoch: 0m 19s
# Epoch 99/99
# ----------
# train Loss: 0.8361 Acc: 0.6941
# test Loss: 2.0398 Acc: 0.3412
# Time taken for epoch: 0m 20s

# %%
# Save the model
torch.save(model.state_dict(), f'model_{num_epochs}.pth')
